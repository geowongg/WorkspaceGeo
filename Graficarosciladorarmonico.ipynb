# %% [markdown]
# <a href="https://colab.research.google.com/github/geowongg/WorkspaceGeo/blob/main/Graficarosciladorarmonico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#graficar oscilador armonico 
#autor:Georgina Wong Ovando
#fecha:30 de Agosto, 2021

import matplotlib.pyplot as plt 
import numpy as np 

def HarmonicOs(amplitud, periodo,tiempo):
  return amplitud*np.sin((2*np.pi/periodo)*tiempo)

tiempo= np.arange (0.0, 10.0, 0.01)
#inicializar variables
print("Datos para gráficar al oscilador armónico")
amplitud= float (input("Ingresa el valor de la amplitud: "))
periodo= float (input("Ingresa el valor del periodo en segundos "))


plt.plot(tiempo, HarmonicOs(amplitud, periodo, tiempo))
plt.show()
# Out:
# Datos para gráficar al oscilador armónico
# Ingresa el valor de la amplitud: 5
# Ingresa el valor del periodo en segundos 5

# %%
#Gráficar oscilador armónico y su derivada 
#autor: Georgina Wong
#fecha: Septiembre 1, 2021

import matplotlib.pyplot as plt 
import numpy as np 

def HarmonicMov(amplitud, periodo, tpunto):
  return amplitud*np.sin((2*np.pi/periodo)*tpunto)
#Derivada de la función
def HarmonicMovprima(amplitud, periodo, tpunto):
  f_det= HarmonicMov(amplitud,periodo,tpunto)
  f_detmash= amplitud*np.sin((2*np.pi/periodo)*(tpunto+h))
  return (f_detmash - f_det)/h
#cos(tpunto) usar id sen(a+b)

tiempo= np.arange(0, 10, 0.1)

#Pedir variables
print("Ingresa los datos para gráficar el oscilador armónico y su derivada")
amplitud= float (input("Amplitud del oscilador: "))
periodo= float (input("Periodo del oscilador en segundos: "))
h= float (input("Intervalo de tiempo para calcular la derivada: "))
tpunto= float (input("Punto en el que quieres evaluar a la derivada de Asen(wt): "))
print("La derivada evaluada en el punto dado es: ")
print(HarmonicMovprima(amplitud,periodo, tpunto))

plt.plot(tiempo, HarmonicMov(amplitud, periodo, tiempo))
plt.plot(tiempo, HarmonicMovprima(amplitud, periodo, tiempo+h))
plt.show()
# Out:
# Ingresa los datos para gráficar el oscilador armónico y su derivada
# Amplitud del oscilador: 5
# Periodo del oscilador en segundos: 2
# Intervalo de tiempo para calcular la derivada: .5
# Punto en el que quieres evaluar a la derivada de Asen(wt): 3
# La derivada evaluada en el punto dado es:
# -10.000000000000004

# %%
#Gráficar oscilador armónico y su derivada 
#autor: Georgina Wong
#fecha: Septiembre 1, 2021

import matplotlib.pyplot as plt 
import numpy as np 


def HarmonicMov(amplitud, periodo, tpunto):
  return amplitud*np.sin((2*np.pi/periodo)*tpunto)

def HarmonicMovprima(amplitud, periodo, tpunto):
  return amplitud*(2*np.pi/periodo)*np.cos((2*np.pi/periodo)*tpunto)

tiempo= np.arange(0, 10, 0.1)

#Pedir variables
print("Ingresa los datos para gráficar el oscilador armónico y su derivada")
amplitud= float (input("Amplitud del oscilador: "))
periodo= float (input("Periodo del oscilador en segundos: "))
h= float (input("Intervalo de tiempo para calcular la derivada: "))
tpunto= float (input("Punto en el que quieres evaluar a la derivada de Asen(wt): "))
print("La derivada evaluada en el punto dado es: ", Harmonicmovdev(amplitud,periodo, tpunto))
print("La derivada exacta evaluada en el punto dado es: ", HarmonicMovprima(amplitud, periodo, tpunto))



plt.plot(tiempo, HarmonicMov(amplitud, periodo, tiempo))
plt.plot(tiempo, HarmonicMovprima(amplitud, periodo, tiempo))
plt.show()
# Out:
# Ingresa los datos para gráficar el oscilador armónico y su derivada
# Amplitud del oscilador: 5
# Periodo del oscilador en segundos: 2
# Intervalo de tiempo para calcular la derivada: .01
# Punto en el que quieres evaluar a la derivada de Asen(wt): 3
# La derivada evaluada en el punto dado es:  -15.705379539064056
# La derivada exacta evaluada en el punto dado es:  -15.707963267948966
